# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# mengakses Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/data-mining/pertemuan5/index.csv'
df = pd.read_csv(file_path)

# %%
# Inisialisasi objek MinMaxScaler
scaler = MinMaxScaler()

# Fit dan transformasi data menggunakan Min-Max Scaling
scaled_data = scaler.fit_transform(data)

print("Dataset asli:")
print(df.head())
print("\n" + "="*50 + "\n")

print("\nData setelah Min-Max Scaling:")
print(min_max_scaled_data)
# Out:
# Dataset asli:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte
#
# ...
#
#
# Data setelah Min-Max Scaling:
# [[0.94058501]
#  [0.94058501]
#  [0.94058501]
#  ...
#  [0.80621572]
#  [0.80621572]
#  [0.80621572]]

# %%
scaler = StandardScaler()
z_score_scaled_data = scaler.fit_transform(data)

print("\nData setelah Z-Score Transformation:")
print(z_score_scaled_data)
# Out:
# Data setelah Z-Score Transformation:
# [[1.34899625]
#  [1.34899625]
#  [1.34899625]
#  ...
#  [0.78480159]
#  [0.78480159]
#  [0.78480159]]

# %%
scaling_factor = 100
decimal_scaled_data = data / scaling_factor
decimal_scaled_df = pd.DataFrame(decimal_scaled_data, columns=['money_decimal'])

print("\nData setelah Decimal Scaling:")
print(decimal_scaled_df.head())
# Out:
# Data setelah Decimal Scaling:
#    money_decimal
# 0          0.387
# 1          0.387
# 2          0.387
# 3          0.289
# 4          0.387
